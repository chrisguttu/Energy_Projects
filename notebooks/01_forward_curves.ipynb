# %%
from src.data_loader import download_yfinance, save_processed
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-eaa553e6df18> in <module>
# ----> 1 from src.data_loader import download_yfinance, save_processed
#       2
#       3
#
# ModuleNotFoundError: No module named 'src'

# %%
symbols = {
    "EUA": "EUA=F",
    "TTF": "TTF=F",
    "Power": "F3AL.F"
}

for name, sym in symbols.items():
    print(f"Downloading {name}...")
    df = download_yfinance(sym, start="2025-01-01", end="2025-10-01")
    save_processed(df, name)
    print(f"{name} saved. Shape: {df.shape}")
# Out:
# ...
# Failed to get ticker 'EUA=F' reason: Expecting value: line 1 column 1 (char 0)
# [*********************100%***********************]  1 of 1 completed
#
# 1 Failed download:
# - EUA=F: No data found for this date range, symbol may be delisted
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-80bbaeb2a1ca> in <module>
#       8     print(f"Downloading {name}...")
#       9     df = download_yfinance(sym, start="2025-01-01", end="2025-10-01")
# ---> 10     save_processed(df, name)
#      11     print(f"{name} saved. Shape: {df.shape}")
#
# <ipython-input-3-546e89c803b9> in save_processed(data, name)
#      19 def save_processed(data: pd.DataFrame, name: str):
#      20     """Save processed data to /data/processed."""
# ---> 21     config = load_config()
#      22     path = os.path.join(config['data']['processed'], f"{name}.csv")
# ...
