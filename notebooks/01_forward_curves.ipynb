# %%
import sys
import os
import matplotlib.pyplot as plt
import pandas as pd

# tell the notebook where to look
sys.path.append(os.path.abspath(os.path.join(os.getcwd(), "..", "src")))

# Import functions
from data_loader import get_commodity, get_multiple_commodities

# specify API key for Alpha Vantage
api_key = "Q0V9QQQHF656ZKDB"

# %% [markdown]
# ## Load a single commodity

# %%
test = get_commodity("COPPER", api_key)

# %%
plt.plot(test.dropna())

# %% [markdown]
# ## Load multiple commodities

# %%
# load data

commodities = ["GOLD", "WTI", "BRENT", "NATURAL_GAS", "COPPER"]

df_all = get_multiple_commodities(commodities, api_key)

print(df_all.tail())
# Out:
# ⚠️ Skipped GOLD: No data returned for GOLD. Response: {'Information': 'We have detected your API key as Q0V9QQQHF656ZKDB and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# ⚠️ Skipped WTI: No data returned for WTI. Response: {'Information': 'We have detected your API key as Q0V9QQQHF656ZKDB and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# ⚠️ Skipped BRENT: No data returned for BRENT. Response: {'Information': 'We have detected your API key as Q0V9QQQHF656ZKDB and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# ⚠️ Skipped NATURAL_GAS: No data returned for NATURAL_GAS. Response: {'Information': 'We have detected your API key as Q0V9QQQHF656ZKDB and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# ⚠️ Skipped COPPER: No data returned for COPPER. Response: {'Information': 'We have detected your API key as Q0V9QQQHF656ZKDB and our standard API rate limit is 25 requests per day. Please subscribe to any of the premium plans at https://www.alphavantage.co/premium/ to instantly remove all daily rate limits.'}
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-5-44e5ec964e87> in <module>
#       3 commodities = ["GOLD", "WTI", "BRENT", "NATURAL_GAS", "COPPER"]
#       4
# ----> 5 df_all = get_multiple_commodities(commodities, api_key)
#       6
#       7 print(df_all.tail())
#
# c:\Users\chris\OneDrive\Documents\Energy_Projects\src\data_loader.py in get_multiple_commodities(commodities, api_key)
#      39
#      40     # Combine all on date index
# ---> 41     combined = pd.concat(all_data, axis=1)
#      42     return combined
#      43
#
# c:\Users\chris\pyver\anaconda\lib\site-packages\pandas\core\reshape\concat.py in concat(objs, axis, join, ignore_index, keys, levels, names, verify_integrity, sort, copy)
#     272     ValueError: Indexes have overlapping values: ['a']
#     273     """
# --> 274     op = _Concatenator(
#     275         objs,
#     276         axis=axis,
#
# c:\Users\chris\pyver\anaconda\lib\site-packages\pandas\core\reshape\concat.py in __init__(self, objs, axis, join, keys, levels, names, ignore_index, verify_integrity, copy, sort)
#     329
#     330         if len(objs) == 0:
# --> 331             raise ValueError("No objects to concatenate")
#     332
#     333         if keys is None:
#
# ValueError: No objects to concatenate

# %%
df_all.dropna(inplace = True)
plt.plot(df_all)
plt.title("Commodity Prices Over Time")
# Out:
# Text(0.5, 1.0, 'Commodity Prices Over Time')

# %%
# pip install yfinance pandas
import yfinance as yf
import pandas as pd

tickers = {
    'WTI_Crude': 'CL=F',     # WTI crude future on Yahoo
    'Brent': 'BZ=F',         # Brent
    'NatGas': 'NG=F'         # Henry Hub natural gas
}

start = '2015-01-01'
end = '2025-10-25'

for name, t in tickers.items():
    df = yf.download(t, start=start, end=end, progress=False)
    df.to_csv(f'./beta_estimation_for_futures/{name}.csv')
    print(f'saved {name}.csv, {len(df)} rows')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 2
#       1 # pip install yfinance pandas
# ----> 2 import yfinance as yf
#       3 import pandas as pd
#       5 tickers = {
#       6     'WTI_Crude': 'CL=F',     # WTI crude future on Yahoo
#       7     'Brent': 'BZ=F',         # Brent
#       8     'NatGas': 'NG=F'         # Henry Hub natural gas
#       9 }
#
# ModuleNotFoundError: No module named 'yfinance'
